# %%
#Print Welcome to Assignment-1
print("Welcome to Assignment-1")
# Out:
# Welcome to Assignment-1

# %%
#Addition output Num1-10,Num2-20,Add=40
num1=int(input("Num1-"))
num2=int(input("Num2-"))
add=num1+num2
print("Add-",add)
# Out:
# Num1- 10
# Num2- 30
# Add- 40

# %%
#BMI Body Mass Index  output Enter the BMI Index:34 Very Overweight
BMI=int(input("Enter the BMI Index:"))
if(BMI<35):
    print("Very Overwight")
# Out:
# Enter the BMI Index: 34
# Very Overwight
